# %% [markdown]
# Дисципліна: обробка біомедичних даних</br>
# Група: БС-83</br>
# Студент: Дольницький Андрій

# %%
import pandas as pd

# %%
import re

# %%
new_df = pd.DataFrame(
{
  "Device": ["Phone", "PC" ,"Laptop"],
    "Model":["Huawei Mate 30 pro", "My PC", "Asus vivobook x1860"],
    "Processor":["Kirin", "Amd", "Intel"],
    "Processor model":["990","Ryzen 2600","i3 7100"]
    
    
}  )
new_df
# Out:
#    Device                Model Processor Processor model
# 0   Phone   Huawei Mate 30 pro     Kirin             990
# 1      PC                My PC       Amd      Ryzen 2600
# 2  Laptop  Asus vivobook x1860     Intel         i3 7100

# %%
path = "/BMD/2017.csv"
data=pd.read_csv(path, encoding = 'utf-8')

print(type(data))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
import os 
print("The directory we working with is in: {}".format(os.getcwd()))
# Out:
# The directory we working with is in: C:\Users\Asus

# %%
data = pd.read_csv('2017.csv')
print(type(data))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
data
# Out:
#                                           LicenseType               Breed  \
# 0                        Dog Individual Spayed Female        BICHON FRISE
# 1      Dog Senior Citizen or Disability Spayed Female           CHIHUAHUA
# 2                        Dog Individual Spayed Female             LAB MIX
# 3                                 Dog Individual Male           DACHSHUND
# 4                        Dog Individual Spayed Female           DACHSHUND
# ...                                               ...                 ...
# 21722                           Dog Individual Female               BOXER
# 21723                    Dog Individual Spayed Female               MIXED
# 21724                             Dog Individual Male  LABRADOR RETRIEVER
# 21725                           Dog Individual Female        GER SHEPHERD
# 21726  Dog Senior Citizen or Disability Neutered Male           CHIHUAHUA
#
#                    Color     DogName  OwnerZip  ExpYear        ValidDate
# ...

# %%
data.dropna(inplace= True)

# %%
perc=[.20, .40, .60, .80]

# %%
include=['object','float','int']

# %%
desc=data.describe(percentiles = perc, include = include)

# %%
desc
# Out:
#                          LicenseType  Breed  Color DogName       ValidDate
# count                          21527  21527  21527   21527           21527
# unique                            16    265     80    5888            1677
# top     Dog Individual Spayed Female  MIXED  BLACK   BELLA  1/5/2017 16:35
# freq                            6378   2287   3079     341             152

# %%
data.dtypes
# Out:
# LicenseType    object
# Breed          object
# Color          object
# DogName        object
# OwnerZip        int64
# ExpYear         int64
# ValidDate      object
# dtype: object

# %%
data.shape
# Out:
# (21527, 7)

# %%
descr=data.describe()

# %%
descr
# Out:
#            OwnerZip  ExpYear
# count  21527.000000  21527.0
# mean   15152.746597   2017.0
# std       85.975201      0.0
# min    15003.000000   2017.0
# 25%    15102.000000   2017.0
# 50%    15137.000000   2017.0
# 75%    15227.000000   2017.0
# max    16229.000000   2017.0

# %%
data['ExpYear'].describe()
# Out:
# count    21527.0
# mean      2017.0
# std          0.0
# min       2017.0
# 25%       2017.0
# 50%       2017.0
# 75%       2017.0
# max       2017.0
# Name: ExpYear, dtype: float64

# %%
data['OwnerZip'].describe()
# Out:
# count    21527.000000
# mean     15152.746597
# std         85.975201
# min      15003.000000
# 25%      15102.000000
# 50%      15137.000000
# 75%      15227.000000
# max      16229.000000
# Name: OwnerZip, dtype: float64

# %%
cut_data=data.iloc[0:10,:]
cut_data
# Out:
#                                       LicenseType         Breed  \
# 0                    Dog Individual Spayed Female  BICHON FRISE
# 1  Dog Senior Citizen or Disability Spayed Female     CHIHUAHUA
# 2                    Dog Individual Spayed Female       LAB MIX
# 3                             Dog Individual Male     DACHSHUND
# 4                    Dog Individual Spayed Female     DACHSHUND
# 5  Dog Senior Citizen or Disability Neutered Male       TERRIER
# 6                           Dog Individual Female       TERRIER
# 7                    Dog Individual Spayed Female       TERRIER
# 8                    Dog Individual Spayed Female  GER SHEPHERD
# 9                    Dog Individual Spayed Female     SCHNOODLE
#
#                Color  DogName  OwnerZip  ExpYear        ValidDate
# 0              WHITE    CHLOE     15090     2017  12/15/2016 9:58
# 1  WHITE/BLACK/BROWN  CHALUPA     15120     2017  3/23/2017 14:32
# ...

# %%
new_data = ["gr1", "gr1", "gr1", "gr1", "gr1", "gr2", "gr2", "gr2", "gr2", "gr2"]
cut_data.insert(1,"Group",new_data)
cut_data
# Out:
#                                       LicenseType Group         Breed  \
# 0                    Dog Individual Spayed Female   gr1  BICHON FRISE
# 1  Dog Senior Citizen or Disability Spayed Female   gr1     CHIHUAHUA
# 2                    Dog Individual Spayed Female   gr1       LAB MIX
# 3                             Dog Individual Male   gr1     DACHSHUND
# 4                    Dog Individual Spayed Female   gr1     DACHSHUND
# 5  Dog Senior Citizen or Disability Neutered Male   gr2       TERRIER
# 6                           Dog Individual Female   gr2       TERRIER
# 7                    Dog Individual Spayed Female   gr2       TERRIER
# 8                    Dog Individual Spayed Female   gr2  GER SHEPHERD
# 9                    Dog Individual Spayed Female   gr2     SCHNOODLE
#
#                Color  DogName  OwnerZip  ExpYear        ValidDate
# 0              WHITE    CHLOE     15090     2017  12/15/2016 9:58
# ...

# %%
cut_data.groupby('Group').describe()
# Out:
#       OwnerZip                                                          \
#          count     mean        std      min      25%      50%      75%
# Group
# gr1        5.0  15111.8  15.974980  15090.0  15108.0  15108.0  15120.0
# gr2        5.0  15226.0  16.537835  15202.0  15218.0  15228.0  15241.0
#
#                ExpYear
#            max   count    mean  std     min     25%     50%     75%     max
# Group
# gr1    15133.0     5.0  2017.0  0.0  2017.0  2017.0  2017.0  2017.0  2017.0
# gr2    15241.0     5.0  2017.0  0.0  2017.0  2017.0  2017.0  2017.0  2017.0

# %%
cut_data.to_csv("output.csv", encoding='utf=8')

# %%
data.to_csv("output_stat.csv", encoding='utf=8')
