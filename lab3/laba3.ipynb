# %% [markdown]
# Дисципліна: обробка біомедичних даних<br> Група: БС-83<br> Студент: Дольницький Андрій<br> Лабораторна №3

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.distplot(tips['tip'])

# %%
sns.jointplot(x="tip",y='total_bill',data=tips,kind='kde')

# %%
sns.pairplot(tips,hue='sex')

# %%
sns.barplot(x='sex',y='total_bill',data=tips)

# %%
sns.boxplot(x='day',y='total_bill', data=tips,palette='Accent')

# %%
sns.stripplot(x='day',y='total_bill',data=tips)

# %%
sns.heatmap(tips.corr())

# %%
g= sns.FacetGrid(tips, col="time", row="smoker")
g= g.map(plt.hist, "total_bill")
