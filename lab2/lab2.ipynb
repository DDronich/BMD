# %% [markdown]
# Дисципліна: обробка біомедичних даних<br> Група: БС-83<br> Студент: Дольницький Андрій

# %%
# %matplotlib inline

# %%
import numpy as np

# %%
x=np.linspace(0,5,11)
y=x**2

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
plt.plot(x,y)
plt.xlabel('X label')
plt.ylabel('Y label')
plt.title('Title')
# Out:
# Text(0.5, 1.0, 'Title')

# %%
plt.subplot(1,2,1)
plt.plot(x,y,'s')
plt.subplot(1,2,2)
plt.plot(y,x,'v')

# %%
fig=plt.figure()

axes = fig.add_axes([0, 0, 1, 1])

axes.plot(x, y)

axes.set_xlabel('X label')
axes.set_ylabel('Y label')
axes.set_title('Title')
# Out:
# Text(0.5, 1.0, 'Title')

# %%
fig = plt.figure()

axes1=fig.add_axes([0,0,1,1])
axes2=fig.add_axes([0.1,0.5,0.4,0.3])

axes1.plot(x,y,'v')
axes1.set_xlabel('X label')
axes1.set_ylabel('Y label')
axes1.set_title('Title')

axes2.plot(x,y,'s')
axes2.set_xlabel('X label')
axes2.set_ylabel('Y label')
axes2.set_title('Title')
# Out:
# Text(0.5, 1.0, 'Title')

# %%
fig,axes=plt.subplots(nrows=1,ncols=2)

axes[0].plot(x,y)
axes[1].plot(y,x)

# %%
fig, axes = plt.subplots(nrows=4 ,ncols=4)
plt.tight_layout()

# %%
fig=plt.figure()

ax=fig.add_axes([0,0,1,1])

ax.plot(x, x**2, label = "x**2")
ax.plot(x, x**3, label = "x**3")
ax.legend()
fig = plt.figure(figsize=(8,4),dpi=100)

# %%
fig, ax = plt.subplots()
ax.plot(x, x**2, color='black')
ax.plot(x, x**3, label = 'green')

# %%
fig, ax = plt.subplots()
ax.plot(x, x**2, lw=2, ls='dashed')

# %%
fig, ax = plt.subplots()
ax.plot(x, x**2, marker = 'o', markersize=10,
       markerfacecolor = 'orange')

# %%
fig.savefig("figure_lab2.png")

# %%
plt.scatter(x,y)

# %%
from random import sample
data = sample (range (1,1000),100)
plt.hist(data)
# Out:
# (array([ 9., 11., 11., 14.,  7.,  8., 11., 10.,  8., 11.]),
#  array([  8. , 106.8, 205.6, 304.4, 403.2, 502. , 600.8, 699.6, 798.4,
#         897.2, 996. ]),
#  <a list of 10 Patch objects>)

# %%
data = [np.random.normal (0, std, 100) 
        for std in range(1,4)]
plt.boxplot(data,vert=True, patch_artist=True);
